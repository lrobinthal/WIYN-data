# %%
# %matplotlib notebook

import pandas
import numpy
import os
import matplotlib
import matplotlib.pyplot as plt
import datetime
from mpl_toolkits.mplot3d import Axes3D
import mpl_toolkits.axisartist.floating_axes as floating_axes
from matplotlib.projections import PolarAxes

# %%
filename="WIYNqual1thru5.csv"
data=pandas.read_csv(filename)

data['ra']=data['RA']
data['dec']=data['Dec']
data['dist']=data['Distance']

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 512 entries, 0 to 511
# Data columns (total 28 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   # Tile                               512 non-null    object
#  1   NCCS_ID                              512 non-null    int64
#  2   Status                               512 non-null    int64
#  3   RA                                   512 non-null    float64
#  4   Dec                                  512 non-null    float64
#  5   Vmag                                 512 non-null    float64
#  6   err_Vmag                             512 non-null    float64
#  7   Rmag                                 512 non-null    float64
#  8   Imag                                 512 non-null    float64
#  9   VFWHM                                512 non-null    object
#  10  RFWHM                                512 non-null    float64
# ...

# %%
tr = PolarAxes.PolarTransform()
ra0,ra1=numpy.radians(0), numpy.radians(360)
dis0,dis1=-3, 360
dis0, dis1=0, 800
#dis0, dis1=87,92
grid_helper = floating_axes.GridHelperCurveLinear(tr, extremes=(ra0, ra1, dis0, dis1))
print (grid_helper)

# %%
fig=plt.figure()
fig.set_size_inches((6,6))

ax1=floating_axes.FloatingSubplot(fig, 111, grid_helper=grid_helper)  
fig.add_subplot(ax1)

ax1.axis["left"].set_axis_direction("bottom") #ra
ax1.axis["right"].set_axis_direction("top") #dist
#ax1.axis []

ax1.axis["left"].label.set_text(r"Distance")
ax1.axis["top"].label.set_text(r"RA")

aux_ax = ax1.get_aux_axes(tr)
aux_ax.patch = ax1.patch  
ax1.patch.zorder = 0.9  


aux_ax.scatter(data['ra'], data['dist'], data['dec'])
aux_ax.grid(True)
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-30.0, 30.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30)) 
ax.set_xlim((-30,30))
ax.set_zlim((0,60))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (0.0, 60.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((60,120))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (60.0, 120.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((120,180))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (120.0, 180.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((180,240))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (180.0, 240.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((240,300))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (240.0, 300.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((300,360))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (300.0, 360.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((360,420))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (360.0, 420.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((420,480))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (420.0, 480.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((480,540))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (480.0, 540.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((540,600))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (540.0, 600.0)

# %%
r_cone=90.-data['dec']
angle_cone=90.-data['ra']
distance=data['dist']



f_x=numpy.tan(numpy.radians(numpy.sin(numpy.radians(angle_cone))*r_cone))*distance
f_y=numpy.tan(numpy.radians(numpy.cos(numpy.radians(angle_cone))*r_cone))*distance

#print(f_x)

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(f_x, f_y, distance, alpha=1, s=5)
ax.set_zlim((0, numpy.max(distance)))

ax.set_xlabel('Distance (Mpc)')
ax.set_ylabel('Distance (Mpc)')
ax.set_zlabel('Distance (Mpc)')

ax.set_ylim((-30,30))
ax.set_xlim((-30,30))
ax.set_zlim((600,660))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (600.0, 660.0)

# %%
from mpl_toolkits.mplot3d import Axes3D
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.scatter(data['ra'], data['dec'], data['dist'])
ax.set_xlabel('RA (degrees)')
ax.set_ylabel('Declination (degrees)')
ax.set_zlabel('Distance (Mpc)')

alpha=1

ax.set_ylim((80,90))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (80.0, 90.0)

# %%
x=numpy.cos(data['ra'])*numpy.cos(data['dec'])*data['dist']
y=numpy.sin(data['ra'])*numpy.cos(data['dec'])*data['dist']
z=data['dist']

#why is it off by an order of magnitude

fig=plt.figure()
ax=fig.add_subplot(111, projection='3d')
ax.scatter(x, y, z, alpha=1, s=5)

ax.set_zlim((0, numpy.max(distance)))
ax.set_xlim((-400, 300))
ax.set_ylim((-400,300))
# Out:
# <img src="data:image/png;base64,..." width="640">
# (-400.0, 300.0)

# %%
x=numpy.cos(data['ra'])*numpy.cos(data['dec'])*data['dist']
print(x)
# Out:
# 0       -1.922599
# 1      -10.953933
# 2      -11.788509
# 3       18.965272
# 4       12.199228
#           ...
# 507    112.679668
# 508    -96.106652
# 509    350.431968
# 510    177.106056
# 511    743.864220
# Length: 512, dtype: float64
